# %%
import pandas as pd
import openpyxl as xl

# %%
file_name=input('Enter your file here:-')
# Out:
# Enter your file here:-Input_2.xlsx

# %%
df=pd.read_excel(file_name)
df
# Out:
#         Name  id Chapter Tag Concept Test 1 - score  \
# 0    Darshan  34       C8S10                      -
# 1      Durga  35       C8S10                      -
# 2      Idhaz  36       C8S10                      2
# 3    Kishore  37       C8S10                      -
# 4       Mano  38       C8S10                      2
# 5     Nandha  39       C8S10                      -
# 6   Nandhini  40       C8S10                      2
# 7     Rubika  42       C8S10                      3
# 8      Saila  43       C8S10                      2
# 9    Shankar  44       C8S10                      -
# 10     Tarun  45       C8S10                      -
# 11    Thanis  46       C8S10                      -
#
#    Concept Test 1 - time-taken (seconds) Concept Test 1 - answered  \
# 0                                      -                         -
# 1                                      -                         -
# 2                                    125                         5
# 3                                      -                         -
# 4                                    136                         5
# 5                                      -                         -
# 6                                    267                         5
# 7                                    194                         5
# 8                                     33                         5
# 9                                      -                         -
# 10                                     -                         -
# 11                                     -                         -
#
#    Concept Test 1- correct Concept Test 1- wrong Concept Test 1- skipped  \
# 0                        -                     -                       -
# 1                        -                     -                       -
# 2                        2                     3                       0
# 3                        -                     -                       -
# 4                        2                     3                       0
# 5                        -                     -                       -
# 6                        2                     3                       0
# 7                        3                     2                       0
# 8                        2                     3                       0
# 9                        -                     -                       -
# 10                       -                     -                       -
# 11                       -                     -                       -
#
#    Concept Test 2 - score  ... Full Chapter Test 1 - answered  \
# 0                       3  ...                              6
# 1                       -  ...                             10
# 2                       4  ...                             10
# 3                       -  ...                              -
# 4                       3  ...                              -
# 5                       0  ...                              -
# 6                       4  ...                              -
# 7                       3  ...                              -
# 8                       3  ...                             10
# 9                       3  ...                              -
# 10                      -  ...                             10
# 11                      -  ...                             10
#
#    Full Chapter Test 1- correct Full Chapter Test 1- wrong  \
# 0                             3                          3
# 1                             5                          5
# 2                             6                          4
# 3                             -                          -
# 4                             -                          -
# 5                             -                          -
# 6                             -                          -
# 7                             -                          -
# 8                             4                          6
# 9                             -                          -
# 10                            4                          6
# 11                            3                          7
#
#    Full Chapter Test 1- skipped Full Chapter Test 2 - score  \
# 0                             4                           6
# 1                             0                           6
# 2                             0                           8
# 3                             -                           -
# 4                             -                           4
# 5                             -                           1
# 6                             -                           9
# 7                             -                           6
# 8                             0                           -
# 9                             -                           -
# 10                            0                           -
# 11                            0                           7
#
#    Full Chapter Test 2 - time-taken (seconds) Full Chapter Test 2 - answered  \
# 0                                         270                             10
# 1                                        1066                             10
# 2                                         717                             10
# 3                                           -                              -
# 4                                         509                             10
# 5                                          50                             10
# 6                                         474                             10
# 7                                         247                             10
# 8                                           -                              -
# 9                                           -                              -
# 10                                          -                              -
# 11                                        123                             10
#
#    Full Chapter Test 2- correct Full Chapter Test 2- wrong  \
# 0                             6                          4
# 1                             6                          4
# 2                             8                          2
# 3                             -                          -
# 4                             4                          6
# 5                             1                          9
# 6                             9                          1
# 7                             6                          4
# 8                             -                          -
# 9                             -                          -
# 10                            -                          -
# 11                            7                          3
#
#    Full Chapter Test 2- skipped
# 0                             0
# 1                             0
# 2                             0
# 3                             -
# 4                             0
# 5                             0
# 6                             0
# 7                             0
# 8                             -
# 9                             -
# 10                            -
# 11                            0
#
# [12 rows x 57 columns]

# %%
answered=df[['Concept Test 1 - answered','Concept Test 2 - answered','Concept Test 3 - answered','Concept Test 4 - answered','Concept Test 5 - answered','Full Chapter Test 1 - answered',
             'Full Chapter Test 2 - answered','Topic Test 1 - answered','Topic Test 2 - answered']]

# %%
# answered2=answered.iloc[:,[i for i in range(1,10)]]
# answered2
answered2=answered.T

# %%
answered3=pd.melt(answered2)

# %%
answered4=answered3.drop(columns=['variable'])

# %%
df_answered=pd.concat([df,answered4],axis=1)
df_reanswered=df_answered.rename(columns={'value':'answered'})

# %%
correct=df[['Concept Test 1- correct','Concept Test 2- correct','Concept Test 3- correct','Concept Test 4- correct','Concept Test 5- correct','Full Chapter Test 1- correct','Full Chapter Test 2- correct','Topic Test 1- correct','Topic Test 2- correct']]
name=df['Name']
correct=correct.set_index(name)
correct=correct.rename(index={'Name':'name'})

# %%
correct2=correct.T

# %%
correct3=pd.melt(correct2)
correct4=correct3.rename(columns={'value':'correct'})

# %%
df_correct=pd.concat([df_answered,correct4],axis=1)

# %%
df_correct2=df_correct.rename(columns={'value':'answered'})

# %%
score=df[['Concept Test 1 - score','Concept Test 2 - score','Concept Test 3 - score','Concept Test 4 - score','Concept Test 5 - score','Full Chapter Test 1 - score','Full Chapter Test 2 - score','Topic Test 1 - score','Topic Test 2 - score']]
id=df['id']
score=score.set_index(id)

# %%
score2=score.T

# %%
score3=pd.melt(score2)

# %%
score4=score3.rename(columns={'value':'score','id':'Username'})

# %%
df_score=pd.concat([df_correct2,score4],axis=1)

# %%
skipped=df[['Concept Test 1- skipped','Concept Test 2- skipped','Concept Test 3- skipped','Concept Test 4- skipped', 'Concept Test 5- skipped','Full Chapter Test 1- skipped','Full Chapter Test 2- skipped','Topic Test 1- skipped','Topic Test 2- skipped']]
test_name=pd.Series(['Concept Test 1','Concept Test 2','Concept Test 3','Concept Test 4','Concept Test 5','Full Chapter Test 1','Full Chapter Test 2','Topic Test 1','Topic Test 2'])

# %%
skipped2=skipped.T

# %%
skipped3=skipped2.reset_index(drop=True)

# %%
skipped4=skipped3.set_index(test_name)
skipped5=skipped4.reset_index(drop=False)

# %%
skipped6=skipped5.melt(id_vars=['index'])

# %%
skipped7=skipped6.drop(columns=['variable'])

# %%
skipped8=skipped7.rename(columns={'index':'Test Name','value':'skipped'})

# %%
df_skipped=pd.concat([df_score,skipped8],axis=1)

# %%
time_taken=df[['Concept Test 1 - time-taken (seconds)','Concept Test 2 - time-taken (seconds)','Concept Test 3 - time-taken (seconds)','Concept Test 4 - time-taken (seconds)','Concept Test 5 - time-taken (seconds)','Full Chapter Test 1 - time-taken (seconds)','Full Chapter Test 2 - time-taken (seconds)','Topic Test 1 - time-taken (seconds)','Topic Test 2 - time-taken (seconds)']]

# %%
time_taken2=time_taken.T

# %%
time_taken3=pd.melt(time_taken2)

# %%
time_taken4=time_taken3.drop(columns=['variable'])

# %%
time_taken5=time_taken4.rename(columns={'value':'time taken(seconds)'})

# %%
df_time_taken=pd.concat([df_skipped,time_taken5],axis=1)

# %%
wrong=df[['Concept Test 1- wrong','Concept Test 2- wrong','Concept Test 3- wrong','Concept Test 4- wrong','Concept Test 5- wrong','Full Chapter Test 1- wrong','Full Chapter Test 2- wrong','Topic Test 1- wrong','Topic Test 2- wrong']]

# %%
wrong2=wrong.T

# %%
wrong3=pd.melt(wrong2)

# %%
wrong3
# Out:
#      variable value
# 0           0     -
# 1           0     1
# 2           0     0
# 3           0     1
# 4           0     0
# ..        ...   ...
# 103        11     3
# 104        11     7
# 105        11     3
# 106        11     -
# 107        11     6
#
# [108 rows x 2 columns]

# %%
wrong4=wrong3.drop(columns=['variable'])

# %%
wrong5=wrong4.rename(columns={'value':'wrong'})

# %%
df_wrong=pd.concat([df_time_taken,wrong5],axis=1)

# %%
df_wrong
# Out:
#         Name    id Chapter Tag Concept Test 1 - score  \
# 0    Darshan  34.0       C8S10                      -
# 1      Durga  35.0       C8S10                      -
# 2      Idhaz  36.0       C8S10                      2
# 3    Kishore  37.0       C8S10                      -
# 4       Mano  38.0       C8S10                      2
# ..       ...   ...         ...                    ...
# 103      NaN   NaN         NaN                    NaN
# 104      NaN   NaN         NaN                    NaN
# 105      NaN   NaN         NaN                    NaN
# 106      NaN   NaN         NaN                    NaN
# 107      NaN   NaN         NaN                    NaN
#
#     Concept Test 1 - time-taken (seconds) Concept Test 1 - answered  \
# 0                                       -                         -
# 1                                       -                         -
# 2                                     125                         5
# 3                                       -                         -
# 4                                     136                         5
# ..                                    ...                       ...
# 103                                   NaN                       NaN
# 104                                   NaN                       NaN
# 105                                   NaN                       NaN
# 106                                   NaN                       NaN
# 107                                   NaN                       NaN
#
#     Concept Test 1- correct Concept Test 1- wrong Concept Test 1- skipped  \
# 0                         -                     -                       -
# 1                         -                     -                       -
# 2                         2                     3                       0
# 3                         -                     -                       -
# 4                         2                     3                       0
# ..                      ...                   ...                     ...
# 103                     NaN                   NaN                     NaN
# 104                     NaN                   NaN                     NaN
# 105                     NaN                   NaN                     NaN
# 106                     NaN                   NaN                     NaN
# 107                     NaN                   NaN                     NaN
#
#     Concept Test 2 - score  ... Full Chapter Test 2- skipped answered  \
# 0                        3  ...                            0        -
# 1                        -  ...                            0        4
# 2                        4  ...                            0        3
# 3                        -  ...                            -        4
# 4                        3  ...                            0        3
# ..                     ...  ...                          ...      ...
# 103                    NaN  ...                          NaN        5
# 104                    NaN  ...                          NaN       10
# 105                    NaN  ...                          NaN       10
# 106                    NaN  ...                          NaN        -
# 107                    NaN  ...                          NaN       10
#
#         Name correct Username score            Test Name skipped  \
# 0    Darshan       -       34     -       Concept Test 1       -
# 1    Darshan       3       34     3       Concept Test 2       1
# 2    Darshan       3       34     3       Concept Test 3       2
# 3    Darshan       3       34     3       Concept Test 4       1
# 4    Darshan       3       34     3       Concept Test 5       2
# ..       ...     ...      ...   ...                  ...     ...
# 103   Thanis       2       46     2       Concept Test 5       0
# 104   Thanis       3       46     3  Full Chapter Test 1       0
# 105   Thanis       7       46     7  Full Chapter Test 2       0
# 106   Thanis       -       46     -         Topic Test 1       -
# 107   Thanis       4       46     4         Topic Test 2       0
#
#     time taken(seconds) wrong
# 0                     -     -
# 1                   187     1
# 2                   175     0
# 3                    91     1
# 4                    84     0
# ..                  ...   ...
# 103                 108     3
# 104                 183     7
# 105                 123     3
# 106                   -     -
# 107                  73     6
#
# [108 rows x 66 columns]

# %%
# df2=df_wrong.drop(df_wrong.iloc[:,0:55],axis=1)

# %%
cols=df_wrong.columns
df2=df_wrong.drop(columns=cols[0:57],axis=1)

# %%
df2
# Out:
#     answered correct  Username score            Test Name skipped  \
# 0          -       -        34     -       Concept Test 1       -
# 1          4       3        34     3       Concept Test 2       1
# 2          3       3        34     3       Concept Test 3       2
# 3          4       3        34     3       Concept Test 4       1
# 4          3       3        34     3       Concept Test 5       2
# ..       ...     ...       ...   ...                  ...     ...
# 103        5       2        46     2       Concept Test 5       0
# 104       10       3        46     3  Full Chapter Test 1       0
# 105       10       7        46     7  Full Chapter Test 2       0
# 106        -       -        46     -         Topic Test 1       -
# 107       10       4        46     4         Topic Test 2       0
#
#     time taken(seconds) wrong
# 0                     -     -
# 1                   187     1
# 2                   175     0
# 3                    91     1
# 4                    84     0
# ..                  ...   ...
# 103                 108     3
# 104                 183     7
# 105                 123     3
# 106                   -     -
# 107                  73     6
#
# [108 rows x 8 columns]

# %%
df3=pd.concat([df2,correct4['Name']],axis=1)
len(df3.index)
# Out:
# 108

# %%
value=df.iloc[0,2]

# %%
df3['Chapter Tag'] = pd.Series([value for x in range(len(df3.index+1))])

# %%
df3
# Out:
#     answered correct  Username score            Test Name skipped  \
# 0          -       -        34     -       Concept Test 1       -
# 1          4       3        34     3       Concept Test 2       1
# 2          3       3        34     3       Concept Test 3       2
# 3          4       3        34     3       Concept Test 4       1
# 4          3       3        34     3       Concept Test 5       2
# ..       ...     ...       ...   ...                  ...     ...
# 103        5       2        46     2       Concept Test 5       0
# 104       10       3        46     3  Full Chapter Test 1       0
# 105       10       7        46     7  Full Chapter Test 2       0
# 106        -       -        46     -         Topic Test 1       -
# 107       10       4        46     4         Topic Test 2       0
#
#     time taken(seconds) wrong     Name Chapter Tag
# 0                     -     -  Darshan       C8S10
# 1                   187     1  Darshan       C8S10
# 2                   175     0  Darshan       C8S10
# 3                    91     1  Darshan       C8S10
# 4                    84     0  Darshan       C8S10
# ..                  ...   ...      ...         ...
# 103                 108     3   Thanis       C8S10
# 104                 183     7   Thanis       C8S10
# 105                 123     3   Thanis       C8S10
# 106                   -     -   Thanis       C8S10
# 107                  73     6   Thanis       C8S10
#
# [108 rows x 10 columns]

# %%
df_reordered = df3.iloc[:, [8, 2, 9, 4, 0, 1, 3, 5, 6, 7]]
df_reordered
# Out:
#         Name  Username Chapter Tag            Test Name answered correct  \
# 0    Darshan        34       C8S10       Concept Test 1        -       -
# 1    Darshan        34       C8S10       Concept Test 2        4       3
# 2    Darshan        34       C8S10       Concept Test 3        3       3
# 3    Darshan        34       C8S10       Concept Test 4        4       3
# 4    Darshan        34       C8S10       Concept Test 5        3       3
# ..       ...       ...         ...                  ...      ...     ...
# 103   Thanis        46       C8S10       Concept Test 5        5       2
# 104   Thanis        46       C8S10  Full Chapter Test 1       10       3
# 105   Thanis        46       C8S10  Full Chapter Test 2       10       7
# 106   Thanis        46       C8S10         Topic Test 1        -       -
# 107   Thanis        46       C8S10         Topic Test 2       10       4
#
#     score skipped time taken(seconds) wrong
# 0       -       -                   -     -
# 1       3       1                 187     1
# 2       3       2                 175     0
# 3       3       1                  91     1
# 4       3       2                  84     0
# ..    ...     ...                 ...   ...
# 103     2       0                 108     3
# 104     3       0                 183     7
# 105     7       0                 123     3
# 106     -       -                   -     -
# 107     4       0                  73     6
#
# [108 rows x 10 columns]

# %%
#  df_reshaped = df_reordered[(df_reordered['answered'].str.contains('-')==False),(df_reordered['correct'].str.contains('-')==False),(df_reordered['score'].str.contains('-')==False)or(df_reordered['skipped'].str.contains('-')==False)or
#                                 (df_reordered['time taken(seconds)'].str.contains('-')==False)or(df_reordered['wrong'].str.contains('-')==False)]

# %%
df_reshaped=df_reordered[~df_reordered['score'].isin(['-'])]

# %%
df_reshaped.shape
# Out:
# (72, 10)

# %%
df_reshaped.to_excel('Guddu_kumar_output2.xlsx')

# %%
df_reshaped
# Out:
#         Name  Username Chapter Tag            Test Name answered correct  \
# 1    Darshan        34       C8S10       Concept Test 2        4       3
# 2    Darshan        34       C8S10       Concept Test 3        3       3
# 3    Darshan        34       C8S10       Concept Test 4        4       3
# 4    Darshan        34       C8S10       Concept Test 5        3       3
# 5    Darshan        34       C8S10  Full Chapter Test 1        6       3
# ..       ...       ...         ...                  ...      ...     ...
# 102   Thanis        46       C8S10       Concept Test 4        4       2
# 103   Thanis        46       C8S10       Concept Test 5        5       2
# 104   Thanis        46       C8S10  Full Chapter Test 1       10       3
# 105   Thanis        46       C8S10  Full Chapter Test 2       10       7
# 107   Thanis        46       C8S10         Topic Test 2       10       4
#
#     score skipped time taken(seconds) wrong
# 1       3       1                 187     1
# 2       3       2                 175     0
# 3       3       1                  91     1
# 4       3       2                  84     0
# 5       3       4                  74     3
# ..    ...     ...                 ...   ...
# 102     2       1                  70     2
# 103     2       0                 108     3
# 104     3       0                 183     7
# 105     7       0                 123     3
# 107     4       0                  73     6
#
# [72 rows x 10 columns]
